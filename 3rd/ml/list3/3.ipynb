# %%
import pickle
import gzip
import json
import numpy as np

with open("embeddings2.pkl", "rb") as f:
    embeddings = pickle.load(f)
print(embeddings.shape)
# Out:
# (18358, 256)

# %%
with open("item_list2.txt") as f:
    item_ids = [line.strip() for line in f]
print(len(item_ids))
# Out:
# 18358

# %%
meta = {}
with gzip.open("meta_Sports_and_Outdoors.json.gz", "rt", encoding="utf-8") as f:
    for line in f:
        data = json.loads(line)
        asin = data.get("asin")
        if asin:
            meta[asin] = data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 meta = {}
# ----> 2 with gzip.open("meta_Sports.json.gz", "rt", encoding="utf-8") as f:
#       3     for line in f:
#       4         data = json.loads(line)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.12/gzip.py:65, in open(filename, mode, compresslevel, encoding, errors, newline)
#      63 gz_mode = mode.replace("t", "")
#      64 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 65     binary_file = GzipFile(filename, gz_mode, compresslevel)
#      66 elif hasattr(filename, "read") or hasattr(filename, "write"):
#      67     binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.12/gzip.py:201, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     199 try:
# ...
