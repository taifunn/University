# %%
import pickle
import gzip
import json
import numpy as np

with open("embeddings2.pkl", "rb") as f:
    embeddings = pickle.load(f)
print(embeddings.shape)
# Out:
# (18358, 256)

# %%
with open("item_list2.txt") as f:
    item_ids = [line.strip() for line in f]
print(len(item_ids))
# Out:
# 18358

# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('meta_Sports_and_Outdoors.json.gz')
